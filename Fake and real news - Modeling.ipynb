# %%
import pandas as pd
import numpy as np
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
nltk.download('punkt')
from nltk.tokenize import word_tokenize
import string
from nltk.stem.porter import PorterStemmer
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import re
import nltk
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.stem.wordnet import WordNetLemmatizer
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import string

from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score, GridSearchCV
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, f1_score
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.pipeline import Pipeline
import xgboost as xgb
from sklearn.ensemble import RandomForestClassifier

from keras import Sequential
from keras.layers import Embedding, LSTM, Dense, Dropout
from keras.models import load_model


seed = 4353
# Out:
#                                                 text subject  type
# 0  donald trump send embarrass new year eve messa...    News     0
# 1  drunk brag trump staffer start russian collu i...    News     0
# 2  sheriff david clark becom internet joke threat...    News     0
# 3  trump obsess even obama name code websit imag ...    News     0
# 4  pope franci call donald trump christma speechp...    News     0

# %%
training = pd.read_csv('clean.csv')
testing = pd.read_csv('clean.csv')

# %%
sns.distplot(training["type"])

# %%
data.head()
# Out:
#                                                 text subject  type
# 0  donald trump send embarrass new year eve messa...    News     0
# 1  drunk brag trump staffer start russian collu i...    News     0
# 2  sheriff david clark becom internet joke threat...    News     0
# 3  trump obsess even obama name code websit imag ...    News     0
# 4  pope franci call donald trump christma speechp...    News     0

# %%
model1 = GaussianNB()
model2 = MultinomialNB()
model3 = BernoulliNB()

# %%
xtrain = training.drop('type', axis=1)
ytrain = training.loc[:, 'type']
xtest = testing.drop('type', axis=1)
ytest = testing.loc[:, 'type']
# Train the model 
model3.fit(xtrain, ytrain)

# Predict Output 
pred1 = model3.predict(xtest)
# Plot Confusion Matrix
mat = confusion_matrix(pred1, ytest)
from mlxtend.plotting import plot_confusion_matrix
plot_confusion_matrix(mat)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-86-6f2b8e9792b5> in <module>()
#       4 ytest = testing.loc[:, 'type']
#       5 # Train the model
# ----> 6 model3.fit(xtrain, ytrain)
#       7
#       8 # Predict Output
#
# /usr/local/lib/python3.6/dist-packages/sklearn/naive_bayes.py in fit(self, X, y, sample_weight)
#     607         self : object
#     608         """
# --> 609         X, y = self._check_X_y(X, y)
#     610         _, n_features = X.shape
#     611         self.n_features_ = n_features
#
# /usr/local/lib/python3.6/dist-packages/sklearn/naive_bayes.py in _check_X_y(self, X, y)
#     975
#     976     def _check_X_y(self, X, y):
# --> 977         X, y = super()._check_X_y(X, y)
#     978         if self.binarize is not None:
#     979             X = binarize(X, threshold=self.binarize)
#
# ...

# %%
from sklearn import preprocessing
enc = preprocessing.LabelEncoder()

enc.fit(data)
classes = enc.transform(clean.csv)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-76-7683f7cb462c> in <module>()
#       2 enc = preprocessing.LabelEncoder()
#       3
# ----> 4 enc.fit(data)
#       5 classes = enc.transform(clean.csv)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_label.py in fit(self, y)
#     233         self : returns an instance of self.
#     234         """
# --> 235         y = column_or_1d(y, warn=True)
#     236         self.classes_ = _encode(y)
#     237         return self
#
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py in column_or_1d(y, warn)
#     795         return np.ravel(y)
#     796
# --> 797     raise ValueError("bad input shape {0}".format(shape))
#     798
#     799
#
# ValueError: bad input shape (44898, 2)

# %%
model1 = GaussianNB()
model2 = MultinomialNB()
model3 = BernoulliNB()

# %%
X_data = data['text']
y_data = data.type
X_data = X_data.astype(str)

# %%
x_train = training.drop('type', axis=1)
y_train = training.loc[:, 'type']
X_test = testing.drop('type', axis=1)
y_test = testing.loc[:, 'type']

# %%
print('The dataset contans {} rows and {} columns'.format(data.shape[0], data.shape[1]))
# Out:
# The dataset contans 44898 rows and 4 columns

# %%
X_train, X_test, y_train, y_test = train_test_split(training, testing, test_size=0.25)

# %%
model1.fit(X_train, y_train)
predictions = model1.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-81-14b3cac85143> in <module>()
# ----> 1 model1.fit(X_train, y_train)
#       2 predictions = model1.predict(X_test)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/naive_bayes.py in fit(self, X, y, sample_weight)
#     204         self : object
#     205         """
# --> 206         y = column_or_1d(y, warn=True)
#     207         return self._partial_fit(X, y, np.unique(y), _refit=True,
#     208                                  sample_weight=sample_weight)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py in column_or_1d(y, warn)
#     795         return np.ravel(y)
#     796
# --> 797     raise ValueError("bad input shape {0}".format(shape))
#     798
#     799
#
# ValueError: bad input shape (33673, 4)
